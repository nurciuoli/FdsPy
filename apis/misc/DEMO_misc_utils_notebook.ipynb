# %% [markdown]
# ### Get FRED Data

# %%
from apis.misc.utils import get_fred_series

start_date = '2000-01-01'
end_date = '2020-01-01'
frequency = 'q'
series_id = 'GDP'

df = get_fred_series(series_id = series_id,
                        start_date = start_date,
                        end_date = end_date,
                        frequency=frequency)
df
# Out:
#                   GDP
# 2000-01-01  10002.179
# 2000-04-01  10247.720
# 2000-07-01  10318.165
# 2000-10-01  10435.744
# 2001-01-01  10470.231
# ...               ...
# 2019-01-01  21013.085
# 2019-04-01  21272.448
# 2019-07-01  21531.839
# 2019-10-01  21706.532
# 2020-01-01  21538.032
#
# [81 rows x 1 columns]

# %% [markdown]
# ### Get Google Trends

# %%
from apis.misc.utils import get_google_trends

start_date = '2019-01-01'
end_date = '2020-01-01'
df = get_google_trends(['Microsoft'],start_date=start_date,end_date=end_date)
df
# Out:
#             Microsoft  isPartial
# date
# 2019-01-06         91      False
# 2019-01-13         92      False
# 2019-01-20         82      False
# 2019-01-27         99      False
# 2019-02-03         89      False
# 2019-02-10         92      False
# 2019-02-17         92      False
# 2019-02-24         85      False
# 2019-03-03         89      False
# 2019-03-10         89      False
# 2019-03-17         90      False
# 2019-03-24         86      False
# 2019-03-31         85      False
# 2019-04-07         81      False
# 2019-04-14         78      False
# 2019-04-21         81      False
# 2019-04-28         80      False
# 2019-05-05         83      False
# 2019-05-12         83      False
# 2019-05-19         85      False
# 2019-05-26         75      False
# 2019-06-02         77      False
# 2019-06-09         88      False
# 2019-06-16         78      False
# 2019-06-23         82      False
# 2019-06-30         77      False
# 2019-07-07         85      False
# ...
