# %%
import utils as cu
entity_match_request ={
    "input": [{"name":"Apple Inc.","clientId": "abc-123"},
    {"name":"Microsoft Corporation", "clientId": "abc-123"},
    {"name":"Amazon.com, Inc.", "clientId": "abc-123"},
    {"name":"Tesla Inc", "clientId": "abc-123"},
    {"name":"Alphabet Inc. Class A", "clientId": "abc-123"},],
    "includeEntityType": ["PUB"],
    "excludeEntityType": ["EXT"],
    "includeEntitySubType": ["PR"],
    "excludeEntitySubType": ["AR"],
    "includeParent": False
    }

cu.search_symbols(entity_data=entity_match_request)

# %%
import utils as cu
people_match_request ={
    "input": [{"personName":"Andy Jassy",'entity' :'Amazon'},
               {"personName":'Tim Cook','entity':'Apple'}],
    }

cu.search_people(people_data=people_match_request)
# Out:
#     taskId activeRole clientEntity clientFirstName clientLastName  \
# 0     None       true       Amazon            None           None
# 1     None      false       Amazon            None           None
# 2     None       true       Amazon            None           None
# 3     None       true       Amazon            None           None
# 4     None       true       Amazon            None           None
# ..     ...        ...          ...             ...            ...
# 280   None       true        Apple            None           None
# 281   None      false        Apple            None           None
# 282   None      false        Apple            None           None
# 283   None       true        Apple            None           None
# 284   None      false        Apple            None           None
#
#     clientMiddleName clientSalutation clientSuffix clientPriority  \
# 0               None             None         None           None
# 1               None             None         None           None
# 2               None             None         None           None
# 3               None             None         None           None
# 4               None             None         None           None
# ..               ...              ...          ...            ...
# 280             None             None         None           None
# 281             None             None         None           None
# 282             None             None         None           None
# 283             None             None         None           None
# 284             None             None         None           None
#
#     clientPersonName  ... clientId                     entity mapStatus  \
# 0         Andy Jassy  ...     None             AMAZON COM INC    MAPPED
# 1         Andy Jassy  ...     None         HARVARD UNIVERSITY      None
# 2         Andy Jassy  ...     None           RAINIER SCHOLARS      None
# 3         Andy Jassy  ...     None    HARVARD BUSINESS SCHOOL      None
# 4         Andy Jassy  ...     None               RAINIER PREP      None
# ..               ...  ...      ...                        ...       ...
# 280         Tim Cook  ...     None  URBAN ELEVATOR SERVICE FL      None
# 281         Tim Cook  ...     None              Athenex, Inc.      None
# 282         Tim Cook  ...     None      Pushpay Holdings Ltd.      None
# 283         Tim Cook  ...     None   MERCK SHARP & DOHME CORP      None
# 284         Tim Cook  ...     None          Deltic Energy Plc      None
#
#     matchFlag            nameMatchSource              nameMatchString  \
# 0        true  Institutional Affiliation                 andrew jassy
# 1       false  Institutional Affiliation                 andrew jassy
# 2       false  Institutional Affiliation                 andrew jassy
# 3       false  Institutional Affiliation                 andrew jassy
# 4       false  Institutional Affiliation                 andrew jassy
# ..        ...                        ...                          ...
# 280     false  Institutional Affiliation                 timothy cook
# 281     false  Institutional Affiliation          cook timothy devere
# 282     false  Institutional Affiliation  cook timothy john /pushpay/
# 283     false  Institutional Affiliation                    tim cooke
# 284     false  Institutional Affiliation           cooke tim /deltic/
#
#     rowIndex similarityScore                                          title  \
# 0          0          1.0000  President, Chief Executive Officer & Director
# 1          0          1.0000                                           None
# 2          0          1.0000                                        Trustee
# 3          0          1.0000                                           None
# 4          0          1.0000                                       Chairman
# ..       ...             ...                                            ...
# 280        1          1.0000                     Co-Chief Executive Officer
# 281        1          1.0000                                           None
# 282        1          1.0000                                           None
# 283        1          0.7756                   Head-IT & Quality Management
# 284        1          0.7756                                           None
#
#     universeId
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ..         ...
# 280       None
# 281       None
# 282       None
# 283       None
# 284       None
#
# [285 rows x 28 columns]

# %%
df = cu.id_lookup('Bloomberg Barclays Agg',search_type = ['indices'],result_limit=5)
df
# Out:
#              index     ticker  \
# symbol
# LHMN30587  indices  LHMN30587
# LHMN27452  indices  LHMN27452
# LHMN27453  indices  LHMN27453
# LHMN27454  indices  LHMN27454
# LHMN10521  indices  LHMN10521
#
#                                                         name
# symbol
# LHMN30587      Bloomberg Barclays US Aggregate Zero Duration
# LHMN27452  Bloomberg Barclays US Aggregate x MBS 3Y Rolldown
# LHMN27453  Bloomberg Barclays US Aggregate x MBS 5Y Rolldown
# LHMN27454  Bloomberg Barclays US Aggregate x MBS 7Y Rolldown
# LHMN10521  Bloomberg Barclays Global Aggregate x Treasury...
