# %%
import utils as cu
entity_match_request ={
    "input": [{"name":"Apple Inc.","clientId": "abc-123"},
    {"name":"Microsoft Corporation", "clientId": "abc-123"},
    {"name":"Amazon.com, Inc.", "clientId": "abc-123"},
    {"name":"Tesla Inc", "clientId": "abc-123"},
    {"name":"Alphabet Inc. Class A", "clientId": "abc-123"},
    {"name":"Berkshire Hathaway Inc. Class B", "clientId": "abc-123"},
    {"name":"Johnson & Johnson", "clientId": "abc-123"},
    {"name":"JPMorgan Chase & Co.", "clientId": "abc-123"},
    {"name":"Visa Inc. Class A", "clientId": "abc-123"},
    {"name":"NVIDIA Corporation", "clientId": "abc-123"},
    {"name":"UnitedHealth Group Incorporated", "clientId": "abc-123"},
    {"name":"Procter & Gamble Company", "clientId": "abc-123"},
    {"name":"Walt Disney Company", "clientId": "abc-123"},
    {"name":"Home Depot, Inc.", "clientId": "abc-123"},
    {"name":"Mastercard Incorporated Class A", "clientId": "abc-123"},
    {"name":"PayPal Holdings Inc", "clientId": "abc-123"},
    {"name":"Netflix, Inc.", "clientId": "abc-123"},
    {"name":"Intel Corporation", "clientId": "abc-123"},
    {"name":"Bank of America Corp", "clientId": "abc-123"},
    {"name":"Verizon Communications Inc.", "clientId": "abc-123"},
    {"name":"Adobe Inc.", "clientId": "abc-123"},
    {"name":"Comcast Corporation Class A", "clientId": "abc-123"},
    {"name":"AT&T Inc.", "clientId": "abc-123"},
    {"name":"Merck & Co., Inc.", "clientId": "abc-123"}],
    "includeEntityType": ["PUB"],
    "excludeEntityType": ["EXT"],
    "includeEntitySubType": ["PR"],
    "excludeEntitySubType": ["AR"],
    "includeParent": False
    }

cu.search_symbols(entity_match_request=entity_match_request)
# Out:
# c:\Users\nurciuoli\nau_projects\FdsPy\FdsPy\content\utils.py:28: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   entity_match_df = json_normalize(entity_match_data['data'])
#     taskId universeId clientId clientBbgFigi clientBbgTicker clientBic  \
# 0     None       None  abc-123          None            None      None
# 1     None       None  abc-123          None            None      None
# 2     None       None  abc-123          None            None      None
# 3     None       None  abc-123          None            None      None
# 4     None       None  abc-123          None            None      None
# ..     ...        ...      ...           ...             ...       ...
# 475   None       None  abc-123          None            None      None
# 476   None       None  abc-123          None            None      None
# 477   None       None  abc-123          None            None      None
# 478   None       None  abc-123          None            None      None
# 479   None       None  abc-123          None            None      None
#
#     clientCik clientCountry clientCrd clientCusip  ... locationCity  \
# 0        None          None      None        None  ...    Cupertino
# 1        None          None      None        None  ...      Beijing
# 2        None          None      None        None  ...      Saitama
# 3        None          None      None        None  ...         None
# 4        None          None      None        None  ...         None
# ..        ...           ...       ...         ...  ...          ...
# 475      None          None      None        None  ...    Darmstadt
# 476      None          None      None        None  ...       Vienna
# 477      None          None      None        None  ...        Espoo
# 478      None          None      None        None  ...       Bogota
# 479      None          None      None        None  ...    Hoeilaart
#
#                            regionName factsetIndustryCode  \
# 0                       North America                1320
# 1                            Far East                None
# 2                            Far East                None
# 3                       North America                None
# 4    Indian Subcontinent/Central Asia                None
# ..                                ...                 ...
# 475                            Europe                2305
# 476                            Europe                2310
# 477                            Europe                2305
# 478                     South America                2310
# 479                            Europe                3308
#
#                  factsetIndustryName factsetSectorCode      factsetSectorName  \
# 0       Telecommunications Equipment              1300  Electronic Technology
# 1                               None              None                   None
# 2                               None              None                   None
# 3                               None              None                   None
# 4                               None              None                   None
# ..                               ...               ...                    ...
# 475           Pharmaceuticals: Major              2300      Health Technology
# 476           Pharmaceuticals: Other              2300      Health Technology
# 477           Pharmaceuticals: Major              2300      Health Technology
# 478           Pharmaceuticals: Other              2300      Health Technology
# 479  Information Technology Services              3300    Technology Services
#
#       parentName parentMatchFlag     nameMatchString     nameMatchSource
# 0           None           False           apple inc  Proper/ Legal Name
# 1           None           False               apple  Proper/ Legal Name
# 2           None           False  apple kk /saitama/  Proper/ Legal Name
# 3           None           False           apple ltd  Proper/ Legal Name
# 4           None           False      apple corp ltd  Proper/ Legal Name
# ..           ...             ...                 ...                 ...
# 475         None           False          merck kgaa  Proper/ Legal Name
# 476   Merck KGaA           False          merck gmbh  Proper/ Legal Name
# 477   Merck KGaA           False            merck oy  Proper/ Legal Name
# 478   Merck KGaA           False            merck sa  Proper/ Legal Name
# 479  E. Merck KG           False            merck nv  Proper/ Legal Name
#
# [480 rows x 62 columns]
