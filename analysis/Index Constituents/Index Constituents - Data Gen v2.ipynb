# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.append(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('"Top 10 Funds by AUM Positioning - Data Gen.ipynb"')))))
sys.path.append(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('"Top 10 Funds by AUM Positioning - Data Gen.ipynb"')))))
import apis.qe.myqengine as qe
from apis.qe.utils import build_multi_bench_universe_expression,build_multi_bench_formulas

# %%
indices = ['R.1000','R.3000']
universe_formula = build_multi_bench_universe_expression(indices)

# %%
formulas = build_multi_bench_formulas(indices)

# %%
formulas.append('FREF_MARKET_VALUE_COMPANY(1,USD,1)')
formulas.append('P_PRICE_RETURNS(1,0,+1/0/0,USD)')
formulas.append('P_PRICE_RETURNS(1,0,+3/0/0,USD)')
formulas.append('P_PRICE_RETURNS(1,0,+12/0/0,USD)')
formulas.append('P_PRICE_RETURNS(1,0,+36/0/0,USD)')

formulas.append('QFL_FCFY(0,CT)')
formulas.append('QFL_DY(0,CT)')
formulas.append('QFL_OCFY(0,CT)')
formulas.append('QFL_INT_BURDEN(0,CT)')
formulas.append('QFL_CFROIC(0,CT)')
formulas.append('QFL_RES_RET_MOM(0,252D)')

# %%
time_series = qe.TimeSeries(start_date = '19991231',end_date = '20191231', frequency='M',calendar='NAY')

univ = qe.ScreenUniverse(universe_formula)
req = qe.calculate(universe = univ, dates = time_series,formulas = formulas)

req.data
# Out:
#             DATE UNIVERSE  ZAV(FG_CONSTITUENTS(R.1000,0,CLOSE))  \
# 0       19991231    CORSQ                                   0.0
# 1       19991231      MCS                                   0.0
# 2       19991231     CTAS                                   1.0
# 3       19991231      HAR                                   0.0
# 4       19991231     BANF                                   0.0
# ...          ...      ...                                   ...
# 712011  20191231     NERV                                   0.0
# 712012  20191231     ABEO                                   0.0
# 712013  20191231     ADEA                                   0.0
# 712014  20191231     CBUS                                   0.0
# 712015  20191231     HARP                                   0.0
#
#         ZAV(FG_CONSTITUENTS(R.3000,0,CLOSE))  \
# 0                                        1.0
# 1                                        1.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
# ...                                      ...
# 712011                                   1.0
# 712012                                   1.0
# 712013                                   1.0
# 712014                                   1.0
# 712015                                   1.0
#
#         FREF_MARKET_VALUE_COMPANY(1,USD,1)  P_PRICE_RETURNS(1,0,+1/0/0,USD)  \
# 0                               329.337006                          3.38541
# 1                               389.564643                        -16.80000
# 2                              5804.504717                        -11.82350
# 3                               983.933950                          4.00891
# 4                               272.540262                        -16.75870
# ...                                    ...                              ...
# 712011                          298.151006                         14.34600
# 712012                          267.833866                        -33.63910
# 712013                          918.429192                        -13.02700
# 712014                          258.665353                        -20.54210
# 712015                          361.932198                        -10.14200
#
#         P_PRICE_RETURNS(1,0,+3/0/0,USD)  P_PRICE_RETURNS(1,0,+12/0/0,USD)  \
# 0                             -0.958329                         108.66400
# 1                             -3.311630                           4.89303
# 2                             11.174100                          50.70350
# 3                              6.993320                          30.42320
# 4                            -21.443800                          18.88770
# ...                                 ...                               ...
# 712011                       -15.330500                         -67.08860
# 712012                       -35.779800                         -51.98780
# 712013                       -23.729700                          15.67570
# 712014                       -52.496400                         -39.80030
# 712015                       -21.703900                          12.30560
#
#         P_PRICE_RETURNS(1,0,+36/0/0,USD)  QFL_FCFY(0,CT)  QFL_DY(0,CT)  \
# 0                                89.6042        9.144028      2.395833
# 1                                10.5860      -13.648150      1.637209
# 2                                31.0306        0.626259      0.414118
# 3                               113.0960       11.586454      0.356347
# 4                                44.9134        8.853490      1.709024
# ...                                  ...             ...           ...
# 712011                          -97.2046      -14.028300      0.000000
# 712012                          -96.2324      -17.722467      0.000000
# 712013                           19.3036       17.730132      4.324325
# 712014                          -97.8959      -16.677113      0.000000
# 712015                          -95.0933       -7.179452      0.000000
#
#         QFL_OCFY(0,CT)  QFL_INT_BURDEN(0,CT)  QFL_CFROIC(0,CT)  \
# 0            10.288486              0.991746          9.902617
# 1            15.476572              0.664243         10.657537
# 2             3.632066              0.923622         21.353880
# 3            17.334110              0.292474         20.464317
# 4            13.144922              0.914576         17.106012
# ...                ...                   ...               ...
# 712011      -14.028302              1.000000        -49.587368
# 712012      -14.334768              1.000000        -25.718822
# 712013       18.698728              0.485942         16.722656
# 712014      -14.978098              1.042677        -29.900986
# 712015       -7.008162              1.000000        -60.940870
#
#         QFL_RES_RET_MOM(0,252D)
# 0                    -26.942434
# 1                    -12.963236
# 2                    -35.409958
# 3                     44.526463
# 4                     -0.888973
# ...                         ...
# 712011               -28.616869
# 712012               -67.350150
# 712013               -29.848188
# 712014               -64.718796
# 712015                      NaN
#
# [712016 rows x 15 columns]

# %%
df = req.data.rename(columns = {'DATE':'date','UNIVERSE':'ticker',
                                    'ZAV(FG_CONSTITUENTS(R.1000,0,CLOSE))':'R.1000',
                                    'ZAV(FG_CONSTITUENTS(R.3000,0,CLOSE))':'R.3000',
                                    'FREF_MARKET_VALUE_COMPANY(1,USD,1)':'market_val',
                                    'P_PRICE_RETURNS(1,0,+1/0/0,USD)':'tret_1mf',
                                    'P_PRICE_RETURNS(1,0,+3/0/0,USD)':'tret_3mf',
                                    'P_PRICE_RETURNS(1,0,+12/0/0,USD)':'tret_12mf',
                                    'P_PRICE_RETURNS(1,0,+36/0/0,USD)':'tret_36mf',
                                    'QFL_FCFY(0,CT)':'fcf_yld',
                                    'QFL_DY(0,CT)':'div_yld',
                                    'QFL_OCFY(0,CT)':'ocf_yld',
                                    'QFL_INT_BURDEN(0,CT)':'int_burden',
                                    'QFL_CFROIC(0,CT)':'cfroic',
                                    'QFL_RES_RET_MOM(0,252D)':'res_mom_252d',
                                    })
                                    

                                    

df= df.set_index(['date','ticker'])
df = df[df['market_val']>0]
df
# Out:
#                  R.1000  R.3000   market_val  tret_1mf   tret_3mf  tret_12mf  \
# date     ticker
# 19991231 CORSQ      0.0     1.0   329.337006   3.38541  -0.958329  108.66400
#          MCS        0.0     1.0   389.564643 -16.80000  -3.311630    4.89303
#          CTAS       1.0     1.0  5804.504717 -11.82350  11.174100   50.70350
#          HAR        0.0     1.0   983.933950   4.00891   6.993320   30.42320
#          BANF       0.0     1.0   272.540262 -16.75870 -21.443800   18.88770
# ...                 ...     ...          ...       ...        ...        ...
# 20191231 NERV       0.0     1.0   298.151006  14.34600 -15.330500  -67.08860
#          ABEO       0.0     1.0   267.833866 -33.63910 -35.779800  -51.98780
#          ADEA       0.0     1.0   918.429192 -13.02700 -23.729700   15.67570
#          CBUS       0.0     1.0   258.665353 -20.54210 -52.496400  -39.80030
#          HARP       0.0     1.0   361.932198 -10.14200 -21.703900   12.30560
#
#                  tret_36mf    fcf_yld   div_yld    ocf_yld  int_burden  \
# date     ticker
# 19991231 CORSQ     89.6042   9.144028  2.395833  10.288486    0.991746
#          MCS       10.5860 -13.648150  1.637209  15.476572    0.664243
#          CTAS      31.0306   0.626259  0.414118   3.632066    0.923622
#          HAR      113.0960  11.586454  0.356347  17.334110    0.292474
#          BANF      44.9134   8.853490  1.709024  13.144922    0.914576
# ...                    ...        ...       ...        ...         ...
# 20191231 NERV     -97.2046 -14.028300  0.000000 -14.028302    1.000000
#          ABEO     -96.2324 -17.722467  0.000000 -14.334768    1.000000
#          ADEA      19.3036  17.730132  4.324325  18.698728    0.485942
#          CBUS     -97.8959 -16.677113  0.000000 -14.978098    1.042677
#          HARP     -95.0933  -7.179452  0.000000  -7.008162    1.000000
#
#                     cfroic  res_mom_252d
# date     ticker
# 19991231 CORSQ    9.902617    -26.942434
#          MCS     10.657537    -12.963236
#          CTAS    21.353880    -35.409958
#          HAR     20.464317     44.526463
#          BANF    17.106012     -0.888973
# ...                    ...           ...
# 20191231 NERV   -49.587368    -28.616869
#          ABEO   -25.718822    -67.350150
#          ADEA    16.722656    -29.848188
#          CBUS   -29.900986    -64.718796
#          HARP   -60.940870           NaN
#
# [711230 rows x 13 columns]

# %%
df.to_pickle('../../data/Index Constituents/universe2_with_char.pkl')
